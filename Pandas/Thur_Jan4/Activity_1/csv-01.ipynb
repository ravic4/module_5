# %% [markdown]
# # Reading a CSV as a Pandas DataFrame

# %% [markdown]
# ### 1. Import libraries and dependencies

# %%
# Import pandas and pathlib
from pathlib import Path
import numpy as np
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### 2. Create a Path to the File Using Pathlib

# %%
# Use the Pathlib libary to set the path to the CSV
people = Path("./people.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Use the Pathlib libary to set the path to the CSV
#       2 people = Path("./people.csv")
# ----> 3 people.head()
#
# AttributeError: 'PosixPath' object has no attribute 'head'

# %% [markdown]
# ### 3. Read the CSV into a Pandas DataFrame

# %%
# Use the file path to read the CSV into a DataFrame
people = pd.read_csv("./people.csv")

people = people.dropna()

# bk = pd.read_csv(bk_data, index_col="date", infer_datetime_format=True, parse_dates=True)

# %% [markdown]
# ### 4. Display a Few Rows of the DataFrame

# %%
# Use the `head` function to display a few rows of the top of the DataFrame
people.head()
# Out:
#     id first_name    last_name                            email  gender  \
# 0  1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1  2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2  3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 4  5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
# 5  6.0    Antonio    Snozzwell            asnozzwell5@mysql.com    Male
#
#                         uni_grad           job_title    Income
# 0              Aurora University  Nurse Practicioner   58135.0
# 1  Osaka University of Economics     Project Manager   96053.0
# 2              Ludong University  Environmental Tech   59196.0
# 4         Boise State University     Project Manager   89073.0
# 5             Babcock University    Technical Writer  119916.0

# %% [markdown]
# ### 5. Generate Summary Statistics on the DataFrame

# %%
# Use the `include` parameter set to 'all' to include all columns (and datatypes)
people.describe(include = "all")
# Out:
#                  id first_name last_name                 email gender  \
# count    957.000000        957       957                   957    957
# unique          NaN        886       942                   956      2
# top             NaN     Israel      Yang  ayang@codedrills.com   Male
# freq            NaN          3         2                     2    483
# mean     500.113898        NaN       NaN                   NaN    NaN
# std      288.628398        NaN       NaN                   NaN    NaN
# min        1.000000        NaN       NaN                   NaN    NaN
# 25%      250.000000        NaN       NaN                   NaN    NaN
# 50%      502.000000        NaN       NaN                   NaN    NaN
# 75%      748.000000        NaN       NaN                   NaN    NaN
# max     1000.000000        NaN       NaN                   NaN    NaN
#
#                       uni_grad              job_title         Income
# count                      957                    957     957.000000
# unique                     907                    183            NaN
# top     University of Portland  Chief Design Engineer            NaN
# freq                         3                     16            NaN
# mean                       NaN                    NaN   84865.983281
# std                        NaN                    NaN   20122.515398
# min                        NaN                    NaN   50013.000000
# 25%                        NaN                    NaN   67761.000000
# 50%                        NaN                    NaN   84284.000000
# 75%                        NaN                    NaN  102461.000000
# max                        NaN                    NaN  119987.000000
