# %% [markdown]
# ### Student Activity: Indexing
#
# This program reads daily stock data from a CSV, trims extraneous columns, sets the date as the index, and calculates and plots returns for a specified date range.

# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Read CSV in as DataFrame

# %%
# Set the path
loans_csv = Path('./loans.csv/')
print(loans_csv)
# Read in the CSV as a DataFrame
loans_csv = pd.read_csv(loans_csv)
# Out:
# loans.csv

# %% [markdown]
# ### Show the First 10 Records

# %%
# Retrive rows with index 0 up to 10 (not including)
loans_csv.iloc[0:1000] #get the first 1,10,100 rows
# Out:
#      loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  \
# 0        10000        10000          10000.0  36 months    0.1033
# 1         4000         4000           4000.0  36 months    0.2340
# 2         5000         5000           5000.0  36 months    0.1797
# 3         9600         9600           9600.0  36 months    0.1298
# 4         2500         2500           2500.0  36 months    0.1356
# ..         ...          ...              ...        ...       ...
# 995      16000        16000          16000.0  36 months    0.0702
# 996      20000        20000          20000.0  60 months    0.1614
# 997      20000        20000          20000.0  36 months    0.0646
# 998       5000         5000           5000.0  36 months    0.1614
# 999      15000        15000          15000.0  36 months    0.1894
#
#      installment grade sub_grade                      emp_title emp_length  \
# 0         324.23     B        B1                            NaN   < 1 year
# 1         155.68     E        E1                       Security    3 years
# 2         180.69     D        D1                 Administrative    6 years
# 3         323.37     B        B5                            NaN        NaN
# 4          84.92     C        C1                           Chef  10+ years
# ..           ...   ...       ...                            ...        ...
# 995       494.18     A        A2                  Bus operator     2 years
# 996       487.86     C        C4                 Merge operator    8 years
# 997       612.62     A        A1         Client success manager    2 years
# 998       176.14     C        C4                 Bather/Stocker    2 years
# 999       549.39     D        D2  Senior underwriting assistant    4 years
#
#     home_ownership  annual_inc verification_status issue_d loan_status  \
# 0         MORTGAGE    280000.0        Not Verified  Dec-18     Current
# 1             RENT     90000.0     Source Verified  Dec-18     Current
# 2         MORTGAGE     59280.0     Source Verified  Dec-18     Current
# 3         MORTGAGE     35704.0        Not Verified  Dec-18     Current
# 4             RENT     55000.0        Not Verified  Dec-18     Current
# ..             ...         ...                 ...     ...         ...
# 995       MORTGAGE    125750.0     Source Verified  Dec-18     Current
# 996       MORTGAGE     62000.0     Source Verified  Dec-18     Current
# 997       MORTGAGE     85000.0        Not Verified  Dec-18     Current
# 998           RENT     15000.0     Source Verified  Dec-18     Current
# 999           RENT     56000.0     Source Verified  Dec-18     Current
#
#     pymnt_plan             purpose
# 0            n  debt_consolidation
# 1            n  debt_consolidation
# 2            n  debt_consolidation
# 3            n    home_improvement
# 4            n  debt_consolidation
# ..         ...                 ...
# 995          n         credit_card
# 996          n         credit_card
# 997          n  debt_consolidation
# 998          n  debt_consolidation
# 999          n         credit_card
#
# [1000 rows x 17 columns]

# %% [markdown]
# ### View Summary Statistics

# %%
# Describe summary statistics for csv data
loans_csv.describe(include = 'all')
# Out:
#             loan_amnt    funded_amnt  funded_amnt_inv       term  \
# count   128412.000000  128412.000000    128412.000000     128412
# unique            NaN            NaN              NaN          2
# top               NaN            NaN              NaN  36 months
# freq              NaN            NaN              NaN      88179
# mean     15971.321021   15971.321021     15968.498166        NaN
# std      10150.384233   10150.384233     10152.168970        NaN
# min       1000.000000    1000.000000       725.000000        NaN
# 25%       8000.000000    8000.000000      8000.000000        NaN
# 50%      14000.000000   14000.000000     14000.000000        NaN
# 75%      21600.000000   21600.000000     21600.000000        NaN
# max      40000.000000   40000.000000     40000.000000        NaN
#
#              int_rate    installment   grade sub_grade emp_title emp_length  \
# count   128412.000000  128412.000000  128412    128412    107465     116708
# unique            NaN            NaN       7        35     43892         11
# top               NaN            NaN       A        A4   Teacher  10+ years
# freq              NaN            NaN   38011      9770      2090      38826
# mean         0.129302     463.259353     NaN       NaN       NaN        NaN
# std          0.050904     285.718256     NaN       NaN       NaN        NaN
# min          0.060000      30.480000     NaN       NaN       NaN        NaN
# 25%          0.084600     253.630000     NaN       NaN       NaN        NaN
# 50%          0.118000     382.905000     NaN       NaN       NaN        NaN
# 75%          0.161400     622.680000     NaN       NaN       NaN        NaN
# max          0.309900    1618.240000     NaN       NaN       NaN        NaN
#
#        home_ownership    annual_inc verification_status issue_d loan_status  \
# count          128412  1.284120e+05              128412  128412      128412
# unique              4           NaN                   3       3           7
# top          MORTGAGE           NaN        Not Verified  Oct-18     Current
# freq            63490           NaN               58350   46305      119540
# mean              NaN  8.279733e+04                 NaN     NaN         NaN
# std               NaN  1.082985e+05                 NaN     NaN         NaN
# min               NaN  0.000000e+00                 NaN     NaN         NaN
# 25%               NaN  4.705800e+04                 NaN     NaN         NaN
# 50%               NaN  6.800000e+04                 NaN     NaN         NaN
# 75%               NaN  9.900000e+04                 NaN     NaN         NaN
# max               NaN  9.757200e+06                 NaN     NaN         NaN
#
#        pymnt_plan             purpose
# count      128412              128412
# unique          1                  12
# top             n  debt_consolidation
# freq       128412               70603
# mean          NaN                 NaN
# std           NaN                 NaN
# min           NaN                 NaN
# 25%           NaN                 NaN
# 50%           NaN                 NaN
# 75%           NaN                 NaN
# max           NaN                 NaN

# %% [markdown]
# ### Filter Columns and Create Subset DataFrame

# %%
# Filter the DataFrame down to the following, keep all rows

#loan_amnt
#term
#int_rate
#emp_title
#annual_inc
#purpose
filtered_df = loans_csv.iloc[:, [0,3,4,8,11,16]] #whole range, and as a list. Get column at index 0,3,4,8
filtered_df.head() #check the top 5 rows and they are put ina brand new data frame
# Out:
#    loan_amnt       term  int_rate       emp_title  annual_inc  \
# 0      10000  36 months    0.1033             NaN    280000.0
# 1       4000  36 months    0.2340        Security     90000.0
# 2       5000  36 months    0.1797  Administrative     59280.0
# 3       9600  36 months    0.1298             NaN     35704.0
# 4       2500  36 months    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %% [markdown]
# ### Filter Rows by 36 Month Terms

# %%
# Conditional indexing to filter DataFrame where 'term' is equal to '36 months'
term_df = filtered_df.loc[filtered_df['term'] == '36 months'].copy()

# %% [markdown]
# ### Modify Row Values

# %%
# Change row values within the 'term' column from '36 months' to '3 Years'
# Out:
#    loan_amnt     term  int_rate       emp_title  annual_inc  \
# 0      10000  3 Years    0.1033         Unknown    280000.0
# 1       4000  3 Years    0.2340        Security     90000.0
# 2       5000  3 Years    0.1797  Administrative     59280.0
# 3       9600  3 Years    0.1298         Unknown     35704.0
# 4       2500  3 Years    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %%
# Change row values within the 'emp_title' column from NaN to 'Unknown'
term_df.loc
# Out:
#    loan_amnt     term  int_rate       emp_title  annual_inc  \
# 0      10000  3 Years    0.1033         Unknown    280000.0
# 1       4000  3 Years    0.2340        Security     90000.0
# 2       5000  3 Years    0.1797  Administrative     59280.0
# 3       9600  3 Years    0.1298         Unknown     35704.0
# 4       2500  3 Years    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %% [markdown]
# ### View Summary Statistics for 3 Year Term Loans

# %%
# Describe summary statistics for three-year loans
# Out:
#            loan_amnt     term      int_rate emp_title    annual_inc  \
# count   88179.000000    88179  88179.000000     88179  8.817900e+04
# unique           NaN        1           NaN     31470           NaN
# top              NaN  3 Years           NaN   Unknown           NaN
# freq             NaN    88179           NaN     15669           NaN
# mean    13279.580456      NaN      0.120610       NaN  8.043616e+04
# std      9479.610905      NaN      0.048955       NaN  1.109251e+05
# min      1000.000000      NaN      0.060000       NaN  0.000000e+00
# 25%      6000.000000      NaN      0.078400       NaN  4.500000e+04
# 50%     10000.000000      NaN      0.110600       NaN  6.500000e+04
# 75%     18000.000000      NaN      0.150200       NaN  9.500000e+04
# max     40000.000000      NaN      0.309900       NaN  9.000000e+06
#
#                    purpose
# count                88179
# unique                  12
# top     debt_consolidation
# freq                 45456
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN

# %% [markdown]
# ### Show Unique Values for Employee Titles with 3 Year Loans

# %%
# Calculate unique values and counts for employee titles of 3 year customer loans
# Out:
# Unknown                                     15669
# Teacher                                      1433
# Manager                                      1207
# Registered Nurse                              672
# Driver                                        654
# RN                                            505
# Supervisor                                    463
# Sales                                         375
# Office Manager                                366
# General Manager                               339
# Project Manager                               338
# Owner                                         272
# Truck Driver                                  263
# Director                                      255
# Operations Manager                            239
# Server                                        228
# Engineer                                      224
# Nurse                                         216
# manager                                       214
# Accountant                                    192
# Sales Manager                                 190
# teacher                                       189
# Administrative Assistant                      187
# Manager                                       178
# Supervisor                                    178
# Account Manager                               167
# Mechanic                                      166
# Vice President                                165
# President                                     162
# Technician                                    154
#                                             ...
# CNO                                             1
# Victim advocate                                 1
# Clinicial Associate                             1
# Mail and supply dept admin                      1
# Oncology Clinical Education Specialist          1
# Cyber analyst                                   1
# loader                                          1
# Testing Manager                                 1
# EHS Coordinator                                 1
# Senior Project Coordinator                      1
# AVP - Senior Finance Accounting Analyst         1
# Appliance delivery                              1
# Delivery Head                                   1
# EDUCATIONAL ASSISTANT                           1
# Delivery load puller                            1
# Director of residential life                    1
# cat scan technologist                           1
# Mortgage Undwrwriter                            1
# Otr lease driver                                1
# Meatclerk                                       1
# Check out supervisor                            1
# Promotions Manager                              1
# Supervisore                                     1
# Assembly Technician                             1
# Bishop                                          1
# Quality Systems Support                         1
# sales marketing                                 1
# Printing specialist                             1
# Construction trade                              1
# Front End                                       1
# Name: emp_title, Length: 31470, dtype: int64

# %% [markdown]
# ### Show Unique Values for Purpose of 3 Year Loans

# %%
# Calculate unique values and counts for loan purposes of 3 year customer loans
# Out:
# debt_consolidation    45456
# credit_card           24780
# other                  5836
# home_improvement       5446
# major_purchase         1795
# medical                1245
# car                     838
# small_business          828
# vacation                749
# house                   596
# moving                  547
# renewable_energy         63
# Name: purpose, dtype: int64

# %% [markdown]
# ### Show Summary Statistics for 3 Year Loans of Customers with Annual Income Greater Than $80,000

# %%
# Display summary statistics where annual income is greater than $80,000 to find count and mean
# Out:
#           loan_amnt      int_rate    annual_inc
# count  29748.000000  29748.000000  2.974800e+04
# mean   18240.116142      0.114116  1.389634e+05
# std    10991.909117      0.048067  1.752361e+05
# min     1000.000000      0.060000  8.000100e+04
# 25%    10000.000000      0.075600  9.500000e+04
# 50%    15700.000000      0.104700  1.120000e+05
# 75%    25000.000000      0.144700  1.500000e+05
# max    40000.000000      0.309400  9.000000e+06

# %% [markdown]
# ### Show Summary Statistics for 3 Year Loans of Customers with Annual Income Less Than $80,000

# %%
# Display summary statistics where annual income is less than $80,000 to find count and mean
# Out:
#           loan_amnt      int_rate    annual_inc
# count  56015.000000  56015.000000  56015.000000
# mean   10607.487727      0.124268  49372.805964
# std     7318.791900      0.049137  16669.098821
# min     1000.000000      0.060000      0.000000
# 25%     5000.000000      0.081900  37000.000000
# 50%     9600.000000      0.113100  50000.000000
# 75%    14000.000000      0.150200  62635.500000
# max    40000.000000      0.309900  79999.000000

# %% [markdown]
# ### What insights can we answer regarding 3 year loans?
#
# 1. What kind of customers (employee title) seem to ask for three-year loans most frequently?
# 2. What are three-year loans generally used for?
# 3. What is the distribution of three-year loan customers with annual incomes greater than 80,000 compared to those with annual incomes less than 80,000?
# 4. What is the difference between interest rates for customers with annual incomes greater than 80,000 compared to those with annual incomes less than 80,000?
